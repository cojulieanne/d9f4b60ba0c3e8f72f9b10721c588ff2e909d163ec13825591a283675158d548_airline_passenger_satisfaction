# %% [markdown]
# # Exploratory Data Analysis
# This noteboook serves as initial analysis on the dataset to inspect properties of data and rationalize any necessary treatments.

# %%
from pathlib import Path
import sys
import os
import numpy as np

project_root = Path(os.getcwd()).resolve().parent
sys.path.append(str(project_root))

# %% [markdown]
# ## 1. Fetch Data
# Data is downloaded from [Kaggle Airline Passenger Satisfaction](https://www.kaggle.com/datasets/teejmahal20/airline-passenger-satisfaction).
# <br>It contains two files: `train.csv` and `test.csv` at a 75%-25% split.
# <br>Datasets were downloaded and saved in `data/` of this repo.

# %%
import pandas as pd
#Load Data
train_df = pd.read_csv(project_root / "data" / "train.csv")
test_df  = pd.read_csv(project_root / "data" / "test.csv")

# %%
print("Train:", train_df.shape, " Test:", test_df.shape)
print("Split Ratio: ", len(test_df)/len(train_df))
# Out:
# Train: (103904, 25)  Test: (25976, 25)
# Split Ratio:  0.25

# %% [markdown]
# ## 2. Data Cleaning

# %% [markdown]
# Both files contain the unncessary column `Unnamed: 0` which we will remove.

# %%
test_df.head()
# Out:
#    Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0           0  19556  Female     Loyal Customer   52  Business travel
# 1           1  90035  Female     Loyal Customer   36  Business travel
# 2           2  12360    Male  disloyal Customer   20  Business travel
# 3           3  77959    Male     Loyal Customer   44  Business travel
# 4           4  36875  Female     Loyal Customer   49  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0       Eco              160                      5
# 1  Business             2863                      1
# 2       Eco              192                      2
# 3  Business             3377                      0
# 4       Eco             1182                      2
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  1  ...                       4
# 2                                  0  ...                       2
# 3                                  0  ...                       1
# 4                                  3  ...                       2
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 5                 5                 5                2
# 1                 4                 4                 4                3
# 2                 4                 1                 3                2
# 3                 1                 1                 1                3
# 4                 2                 2                 2                4
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          50
# 1                 4            5                           0
# 2                 2            2                           0
# 3                 1            4                           0
# 4                 2            4                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      44.0                satisfied
# 1                       0.0                satisfied
# 2                       0.0  neutral or dissatisfied
# 3                       6.0                satisfied
# 4                      20.0                satisfied
#
# [5 rows x 25 columns]

# %%
train_df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# 2                                  2  ...                       5
# 3                                  5  ...                       2
# 4                                  3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      18.0  neutral or dissatisfied
# 1                       6.0  neutral or dissatisfied
# 2                       0.0                satisfied
# 3                       9.0  neutral or dissatisfied
# 4                       0.0                satisfied
#
# [5 rows x 25 columns]

# %%
#Remove unncessary column
train_df = train_df.drop(columns=['Unnamed: 0'])
test_df = test_df.drop(columns=['Unnamed: 0'])

# %% [markdown]
# We also check for uniqueness of the IDs used in the dataset to ensure no duplications.

# %%
print("Train ID uniquness: ", train_df['id'].nunique() == len(train_df))
print("Test ID uniquness: ", test_df['id'].nunique() == len(test_df))
# Out:
# Train ID uniquness:  True
# Test ID uniquness:  True

# %% [markdown]
# ## 3. Combined Data
# For demonstration purpose of the full model development pipeline, the train and test data will be combined. This provides flexibility for the developer to customize the paramters of the split.

# %%
data = pd.concat([train_df, test_df])
data.to_csv('../data/full_data.csv', index = False)
data.shape
# Out:
# (129880, 24)

# %%
print("All ID uniquness: ", data['id'].nunique() == len(data))
# Out:
# All ID uniquness:  True

# %% [markdown]
# ## 4. Target and Features

# %% [markdown]
# The target label of the data is the `satisfaction` column which has values of either: `neutral or dissatisfied` or `satisfied`.
# <br>With `satisfied` as the positive label (1) and `neutral or dissatisfied` as the negative label (0), we observe an event rate of ~43%

# %%
data['satisfaction'].value_counts()/len(data)
# Out:
# satisfaction
# neutral or dissatisfied    0.565537
# satisfied                  0.434463
# Name: count, dtype: float64

# %% [markdown]
# ### Data Types

# %% [markdown]
# Out of 24 columns, 5 columns are categorical -- `Gender`, `Customer Type`, `Type of Travel`, `Class`, and `satisfaction`. These columns will need one-hot-encoding.

# %%
data.dtypes
# Out:
# id                                     int64
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# Cleanliness                            int64
# Departure Delay in Minutes             int64
# Arrival Delay in Minutes             float64
# satisfaction                          object
# dtype: object

# %% [markdown]
# ### Data Summary

# %% [markdown]
# For the numeric columns, aside from `Age`, `Flight Distance`, `Departure Delay in Minutes` and `Arrival Delay in Minutes`, all of the other variables are survey ratings (1 to 5) based on the passengers' survey responses. All variables have good variablity evidenced by the std per column (none that are close to 0). Hence, no columns will be dropped due to low variance.

# %%
data.describe()
# Out:
#                   id            Age  Flight Distance  Inflight wifi service  \
# count  129880.000000  129880.000000    129880.000000          129880.000000
# mean    64940.500000      39.427957      1190.316392               2.728696
# std     37493.270818      15.119360       997.452477               1.329340
# min         1.000000       7.000000        31.000000               0.000000
# 25%     32470.750000      27.000000       414.000000               2.000000
# 50%     64940.500000      40.000000       844.000000               3.000000
# 75%     97410.250000      51.000000      1744.000000               4.000000
# max    129880.000000      85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      129880.000000           129880.000000
# mean                            3.057599                2.756876
# std                             1.526741                1.401740
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# 50%                             3.000000                3.000000
# 75%                             4.000000                4.000000
# max                             5.000000                5.000000
#
#        Gate location  Food and drink  Online boarding   Seat comfort  \
# count  129880.000000   129880.000000    129880.000000  129880.000000
# mean        2.976925        3.204774         3.252633       3.441361
# std         1.278520        1.329933         1.350719       1.319289
# min         0.000000        0.000000         0.000000       0.000000
# 25%         2.000000        2.000000         2.000000       2.000000
# 50%         3.000000        3.000000         3.000000       4.000000
# 75%         4.000000        4.000000         4.000000       5.000000
# max         5.000000        5.000000         5.000000       5.000000
#
#        Inflight entertainment  On-board service  Leg room service  \
# count           129880.000000     129880.000000     129880.000000
# mean                 3.358077          3.383023          3.350878
# std                  1.334049          1.287099          1.316252
# min                  0.000000          0.000000          0.000000
# 25%                  2.000000          2.000000          2.000000
# 50%                  4.000000          4.000000          4.000000
# 75%                  4.000000          4.000000          4.000000
# max                  5.000000          5.000000          5.000000
#
#        Baggage handling  Checkin service  Inflight service    Cleanliness  \
# count     129880.000000    129880.000000     129880.000000  129880.000000
# mean           3.632114         3.306267          3.642193       3.286326
# std            1.180025         1.266185          1.176669       1.313682
# min            1.000000         0.000000          0.000000       0.000000
# 25%            3.000000         3.000000          3.000000       2.000000
# 50%            4.000000         3.000000          4.000000       3.000000
# 75%            5.000000         4.000000          5.000000       4.000000
# max            5.000000         5.000000          5.000000       5.000000
#
#        Departure Delay in Minutes  Arrival Delay in Minutes
# count               129880.000000             129487.000000
# mean                    14.713713                 15.091129
# std                     38.071126                 38.465650
# min                      0.000000                  0.000000
# 25%                      0.000000                  0.000000
# 50%                      0.000000                  0.000000
# 75%                     12.000000                 13.000000
# max                   1592.000000               1584.000000

# %% [markdown]
# ### Missing Values

# %% [markdown]
# Only `Arrival Delay in Minutes` has missing values at 0.3%. For simplicity, we will impute this with zero being the median value for this column.

# %%
data.isna().sum()/len(data)
# Out:
# id                                   0.000000
# Gender                               0.000000
# Customer Type                        0.000000
# Age                                  0.000000
# Type of Travel                       0.000000
# Class                                0.000000
# Flight Distance                      0.000000
# Inflight wifi service                0.000000
# Departure/Arrival time convenient    0.000000
# Ease of Online booking               0.000000
# Gate location                        0.000000
# Food and drink                       0.000000
# Online boarding                      0.000000
# Seat comfort                         0.000000
# Inflight entertainment               0.000000
# On-board service                     0.000000
# Leg room service                     0.000000
# Baggage handling                     0.000000
# Checkin service                      0.000000
# Inflight service                     0.000000
# Cleanliness                          0.000000
# Departure Delay in Minutes           0.000000
# Arrival Delay in Minutes             0.003026
# satisfaction                         0.000000
# dtype: float64

# %% [markdown]
# ### Categorical Columns

# %% [markdown]
# `Gender` column is balanced between Males and Females. Will be One-Hot-Encoded.

# %%
data['Gender'].value_counts()/len(data)
# Out:
# Gender
# Female    0.507384
# Male      0.492616
# Name: count, dtype: float64

# %% [markdown]
# 82% of customers are tagged as loyal under `Customer Type`. Data dictionary did not disclose the basis for this tagging but could be assumed related to repeat bookings and high volumes/frequencies of transactions. Recommended for One-Hot-Encoding

# %%
data['Customer Type'].value_counts()/len(data)
# Out:
# Customer Type
# Loyal Customer       0.816908
# disloyal Customer    0.183092
# Name: count, dtype: float64

# %% [markdown]
# `Class` column refers to ticket tiers with varying prices. This can be label encoded with increasing values in the order of `Eco`, `Eco Plus`, and `Business`.

# %%
data['Class'].value_counts()/len(data)
# Out:
# Class
# Business    0.478596
# Eco         0.448945
# Eco Plus    0.072459
# Name: count, dtype: float64

# %% [markdown]
# 69% of passengers are business travelers (`Type of Travel`). For One-Hot-Encoding.

# %%
data['Type of Travel'].value_counts()/len(data)
# Out:
# Type of Travel
# Business travel    0.690584
# Personal Travel    0.309416
# Name: count, dtype: float64

# %%
data = pd.get_dummies(data, columns=['Gender', 'Customer Type', 'Type of Travel', 'satisfaction'], drop_first=True, dtype=int)

# %% [markdown]
# ### Correlation

# %%
corrmat = data.select_dtypes(include=['number']).corr()
corrmat
# Out:
#                                          id       Age  Flight Distance  \
# id                                 1.000000  0.020322         0.095504
# Age                                0.020322  1.000000         0.099459
# Flight Distance                    0.095504  0.099459         1.000000
# Inflight wifi service             -0.023096  0.016116         0.006701
# Departure/Arrival time convenient -0.002192  0.036960        -0.018914
# Ease of Online booking             0.013400  0.022565         0.065165
# Gate location                     -0.000113 -0.000398         0.005520
# Food and drink                    -0.000510  0.023194         0.057066
# Online boarding                    0.055538  0.207572         0.214825
# Seat comfort                       0.052164  0.159136         0.157662
# Inflight entertainment             0.001620  0.074947         0.130507
# On-board service                   0.055502  0.057078         0.111194
# Leg room service                   0.044088  0.039119         0.134533
# Baggage handling                   0.074569 -0.047991         0.064855
# Checkin service                    0.079325  0.033475         0.073608
# Inflight service                   0.078793 -0.051347         0.059316
# Cleanliness                        0.024048  0.052565         0.095648
# Departure Delay in Minutes        -0.017643 -0.009041         0.002402
# Arrival Delay in Minutes          -0.035657 -0.011248        -0.001935
# Gender_Male                       -0.001361  0.008996         0.003616
# Customer Type_disloyal Customer    0.001467 -0.284172        -0.226021
# Type of Travel_Personal Travel    -0.000935 -0.044808        -0.266792
# satisfaction_satisfied             0.013182  0.134091         0.298085
#
#                                    Inflight wifi service  \
# id                                             -0.023096
# Age                                             0.016116
# Flight Distance                                 0.006701
# Inflight wifi service                           1.000000
# Departure/Arrival time convenient               0.344915
# Ease of Online booking                          0.714807
# Gate location                                   0.338573
# Food and drink                                  0.132214
# Online boarding                                 0.457445
# Seat comfort                                    0.121513
# Inflight entertainment                          0.207802
# On-board service                                0.119928
# Leg room service                                0.160317
# Baggage handling                                0.120376
# Checkin service                                 0.043762
# Inflight service                                0.110029
# Cleanliness                                     0.131300
# Departure Delay in Minutes                     -0.015946
# Arrival Delay in Minutes                       -0.017749
# Gender_Male                                     0.005901
# Customer Type_disloyal Customer                -0.005757
# Type of Travel_Personal Travel                 -0.105865
# satisfaction_satisfied                          0.283460
#
#                                    Departure/Arrival time convenient  \
# id                                                         -0.002192
# Age                                                         0.036960
# Flight Distance                                            -0.018914
# Inflight wifi service                                       0.344915
# Departure/Arrival time convenient                           1.000000
# Ease of Online booking                                      0.437620
# Gate location                                               0.447510
# Food and drink                                              0.000687
# Online boarding                                             0.072287
# Seat comfort                                                0.008666
# Inflight entertainment                                     -0.008380
# On-board service                                            0.067297
# Leg room service                                            0.010617
# Baggage handling                                            0.070833
# Checkin service                                             0.091132
# Inflight service                                            0.072195
# Cleanliness                                                 0.009862
# Departure Delay in Minutes                                  0.000778
# Arrival Delay in Minutes                                   -0.000942
# Gender_Male                                                 0.008995
# Customer Type_disloyal Customer                            -0.206873
# Type of Travel_Personal Travel                              0.257102
# satisfaction_satisfied                                     -0.054270
#
#                                    Ease of Online booking  Gate location  \
# id                                               0.013400      -0.000113
# Age                                              0.022565      -0.000398
# Flight Distance                                  0.065165       0.005520
# Inflight wifi service                            0.714807       0.338573
# Departure/Arrival time convenient                0.437620       0.447510
# Ease of Online booking                           1.000000       0.460041
# Gate location                                    0.460041       1.000000
# Food and drink                                   0.030514      -0.002872
# Online boarding                                  0.404866       0.002756
# Seat comfort                                     0.028561       0.002788
# Inflight entertainment                           0.046564       0.002741
# On-board service                                 0.039064      -0.029019
# Leg room service                                 0.109450      -0.005181
# Baggage handling                                 0.039148       0.000972
# Checkin service                                  0.008819      -0.039353
# Inflight service                                 0.035373       0.000310
# Cleanliness                                      0.015125      -0.005918
# Departure Delay in Minutes                      -0.005318       0.005973
# Arrival Delay in Minutes                        -0.007033       0.005658
# Gender_Male                                      0.005893      -0.000863
# Customer Type_disloyal Customer                 -0.018059       0.004465
# Type of Travel_Personal Travel                  -0.134078      -0.029869
# satisfaction_satisfied                           0.168877      -0.002793
#
#                                    Food and drink  Online boarding  \
# id                                      -0.000510         0.055538
# Age                                      0.023194         0.207572
# Flight Distance                          0.057066         0.214825
# Inflight wifi service                    0.132214         0.457445
# Departure/Arrival time convenient        0.000687         0.072287
# Ease of Online booking                   0.030514         0.404866
# Gate location                           -0.002872         0.002756
# Food and drink                           1.000000         0.233500
# Online boarding                          0.233500         1.000000
# Seat comfort                             0.575846         0.419253
# Inflight entertainment                   0.623461         0.283922
# On-board service                         0.057404         0.154242
# Leg room service                         0.033173         0.123225
# Baggage handling                         0.035321         0.083541
# Checkin service                          0.085198         0.204238
# Inflight service                         0.035210         0.074058
# Cleanliness                              0.658054         0.329377
# Departure Delay in Minutes              -0.029164        -0.019404
# Arrival Delay in Minutes                -0.031715        -0.022730
# Gender_Male                              0.001730        -0.045022
# Customer Type_disloyal Customer         -0.056997        -0.189083
# Type of Travel_Personal Travel          -0.068986        -0.224020
# satisfaction_satisfied                   0.211340         0.501749
#
#                                    Seat comfort  ...  Baggage handling  \
# id                                     0.052164  ...          0.074569
# Age                                    0.159136  ...         -0.047991
# Flight Distance                        0.157662  ...          0.064855
# Inflight wifi service                  0.121513  ...          0.120376
# Departure/Arrival time convenient      0.008666  ...          0.070833
# Ease of Online booking                 0.028561  ...          0.039148
# Gate location                          0.002788  ...          0.000972
# Food and drink                         0.575846  ...          0.035321
# Online boarding                        0.419253  ...          0.083541
# Seat comfort                           1.000000  ...          0.074620
# Inflight entertainment                 0.611837  ...          0.379123
# On-board service                       0.130545  ...          0.520296
# Leg room service                       0.104272  ...          0.371455
# Baggage handling                       0.074620  ...          1.000000
# Checkin service                        0.189979  ...          0.234503
# Inflight service                       0.068842  ...          0.629237
# Cleanliness                            0.679613  ...          0.097071
# Departure Delay in Minutes            -0.027999  ...         -0.004105
# Arrival Delay in Minutes              -0.030521  ...         -0.007935
# Gender_Male                           -0.030756  ...          0.036356
# Customer Type_disloyal Customer       -0.156239  ...          0.024874
# Type of Travel_Personal Travel        -0.127717  ...         -0.033012
# satisfaction_satisfied                 0.348829  ...          0.248680
#
#                                    Checkin service  Inflight service  \
# id                                        0.079325          0.078793
# Age                                       0.033475         -0.051347
# Flight Distance                           0.073608          0.059316
# Inflight wifi service                     0.043762          0.110029
# Departure/Arrival time convenient         0.091132          0.072195
# Ease of Online booking                    0.008819          0.035373
# Gate location                            -0.039353          0.000310
# Food and drink                            0.085198          0.035210
# Online boarding                           0.204238          0.074058
# Seat comfort                              0.189979          0.068842
# Inflight entertainment                    0.119554          0.406094
# On-board service                          0.244619          0.551569
# Leg room service                          0.152693          0.369569
# Baggage handling                          0.234503          0.629237
# Checkin service                           1.000000          0.237601
# Inflight service                          0.237601          1.000000
# Cleanliness                               0.176658          0.090356
# Departure Delay in Minutes               -0.018752         -0.054432
# Arrival Delay in Minutes                 -0.021705         -0.059853
# Gender_Male                               0.008462          0.038504
# Customer Type_disloyal Customer          -0.031243          0.023292
# Type of Travel_Personal Travel            0.016247         -0.023538
# satisfaction_satisfied                    0.237252          0.244918
#
#                                    Cleanliness  Departure Delay in Minutes  \
# id                                    0.024048                   -0.017643
# Age                                   0.052565                   -0.009041
# Flight Distance                       0.095648                    0.002402
# Inflight wifi service                 0.131300                   -0.015946
# Departure/Arrival time convenient     0.009862                    0.000778
# Ease of Online booking                0.015125                   -0.005318
# Gate location                        -0.005918                    0.005973
# Food and drink                        0.658054                   -0.029164
# Online boarding                       0.329377                   -0.019404
# Seat comfort                          0.679613                   -0.027999
# Inflight entertainment                0.692511                   -0.027012
# On-board service                      0.122084                   -0.030486
# Leg room service                      0.096695                    0.014574
# Baggage handling                      0.097071                   -0.004105
# Checkin service                       0.176658                   -0.018752
# Inflight service                      0.090356                   -0.054432
# Cleanliness                           1.000000                   -0.014543
# Departure Delay in Minutes           -0.014543                    1.000000
# Arrival Delay in Minutes             -0.016546                    0.965291
# Gender_Male                           0.002867                    0.003491
# Customer Type_disloyal Customer      -0.081302                    0.003859
# Type of Travel_Personal Travel       -0.084615                   -0.005913
# satisfaction_satisfied                0.307035                   -0.050740
#
#                                    Arrival Delay in Minutes  Gender_Male  \
# id                                                -0.035657    -0.001361
# Age                                               -0.011248     0.008996
# Flight Distance                                   -0.001935     0.003616
# Inflight wifi service                             -0.017749     0.005901
# Departure/Arrival time convenient                 -0.000942     0.008995
# Ease of Online booking                            -0.007033     0.005893
# Gate location                                      0.005658    -0.000863
# Food and drink                                    -0.031715     0.001730
# Online boarding                                   -0.022730    -0.045022
# Seat comfort                                      -0.030521    -0.030756
# Inflight entertainment                            -0.030230     0.003843
# On-board service                                  -0.034789     0.006447
# Leg room service                                   0.011346     0.031047
# Baggage handling                                  -0.007935     0.036356
# Checkin service                                   -0.021705     0.008462
# Inflight service                                  -0.059853     0.038504
# Cleanliness                                       -0.016546     0.002867
# Departure Delay in Minutes                         0.965291     0.003491
# Arrival Delay in Minutes                           1.000000     0.001309
# Gender_Male                                        0.001309     1.000000
# Customer Type_disloyal Customer                    0.004730    -0.030958
# Type of Travel_Personal Travel                    -0.005830     0.009503
# satisfaction_satisfied                            -0.058275     0.011236
#
#                                    Customer Type_disloyal Customer  \
# id                                                        0.001467
# Age                                                      -0.284172
# Flight Distance                                          -0.226021
# Inflight wifi service                                    -0.005757
# Departure/Arrival time convenient                        -0.206873
# Ease of Online booking                                   -0.018059
# Gate location                                             0.004465
# Food and drink                                           -0.056997
# Online boarding                                          -0.189083
# Seat comfort                                             -0.156239
# Inflight entertainment                                   -0.106001
# On-board service                                         -0.054172
# Leg room service                                         -0.046841
# Baggage handling                                          0.024874
# Checkin service                                          -0.031243
# Inflight service                                          0.023292
# Cleanliness                                              -0.081302
# Departure Delay in Minutes                                0.003859
# Arrival Delay in Minutes                                  0.004730
# Gender_Male                                              -0.030958
# Customer Type_disloyal Customer                           1.000000
# Type of Travel_Personal Travel                           -0.308236
# satisfaction_satisfied                                   -0.186017
#
#                                    Type of Travel_Personal Travel  \
# id                                                      -0.000935
# Age                                                     -0.044808
# Flight Distance                                         -0.266792
# Inflight wifi service                                   -0.105865
# Departure/Arrival time convenient                        0.257102
# Ease of Online booking                                  -0.134078
# Gate location                                           -0.029869
# Food and drink                                          -0.068986
# Online boarding                                         -0.224020
# Seat comfort                                            -0.127717
# Inflight entertainment                                  -0.152936
# On-board service                                        -0.059794
# Leg room service                                        -0.139612
# Baggage handling                                        -0.033012
# Checkin service                                          0.016247
# Inflight service                                        -0.023538
# Cleanliness                                             -0.084615
# Departure Delay in Minutes                              -0.005913
# Arrival Delay in Minutes                                -0.005830
# Gender_Male                                              0.009503
# Customer Type_disloyal Customer                         -0.308236
# Type of Travel_Personal Travel                           1.000000
# satisfaction_satisfied                                  -0.449861
#
#                                    satisfaction_satisfied
# id                                               0.013182
# Age                                              0.134091
# Flight Distance                                  0.298085
# Inflight wifi service                            0.283460
# Departure/Arrival time convenient               -0.054270
# Ease of Online booking                           0.168877
# Gate location                                   -0.002793
# Food and drink                                   0.211340
# Online boarding                                  0.501749
# Seat comfort                                     0.348829
# Inflight entertainment                           0.398234
# On-board service                                 0.322205
# Leg room service                                 0.312424
# Baggage handling                                 0.248680
# Checkin service                                  0.237252
# Inflight service                                 0.244918
# Cleanliness                                      0.307035
# Departure Delay in Minutes                      -0.050740
# Arrival Delay in Minutes                        -0.058275
# Gender_Male                                      0.011236
# Customer Type_disloyal Customer                 -0.186017
# Type of Travel_Personal Travel                  -0.449861
# satisfaction_satisfied                           1.000000
#
# [23 rows x 23 columns]

# %% [markdown]
# Most correlated variables to the target are `Online Boarding`, `Type of Travel`, and `Inflight Entertainment`.

# %%
corrmat['satisfaction_satisfied']
# Out:
# id                                   0.013182
# Age                                  0.134091
# Flight Distance                      0.298085
# Inflight wifi service                0.283460
# Departure/Arrival time convenient   -0.054270
# Ease of Online booking               0.168877
# Gate location                       -0.002793
# Food and drink                       0.211340
# Online boarding                      0.501749
# Seat comfort                         0.348829
# Inflight entertainment               0.398234
# On-board service                     0.322205
# Leg room service                     0.312424
# Baggage handling                     0.248680
# Checkin service                      0.237252
# Inflight service                     0.244918
# Cleanliness                          0.307035
# Departure Delay in Minutes          -0.050740
# Arrival Delay in Minutes            -0.058275
# Gender_Male                          0.011236
# Customer Type_disloyal Customer     -0.186017
# Type of Travel_Personal Travel      -0.449861
# satisfaction_satisfied               1.000000
# Name: satisfaction_satisfied, dtype: float64
